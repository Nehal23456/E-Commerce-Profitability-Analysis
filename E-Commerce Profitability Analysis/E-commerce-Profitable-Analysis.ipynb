# %%
import pandas as pd

# %%
df1 = pd.read_csv("C:\\Users\\HP\\Downloads\\products.csv")
df1
# Out:
#     product_id            product_name         category sub_category  \
# 0     SKU-0001  Headphones - Variant 1      Electronics   Headphones
# 1     SKU-0002  Headphones - Variant 2      Electronics   Headphones
# 2     SKU-0003  Headphones - Variant 3      Electronics   Headphones
# 3     SKU-0004  Headphones - Variant 4      Electronics   Headphones
# 4     SKU-0005  Headphones - Variant 5      Electronics   Headphones
# ..         ...                     ...              ...          ...
# 202   SKU-0203      Sauces - Variant 5  Food & Beverage       Sauces
# 203   SKU-0204     Organic - Variant 1  Food & Beverage      Organic
# 204   SKU-0205     Organic - Variant 2  Food & Beverage      Organic
# 205   SKU-0206     Organic - Variant 3  Food & Beverage      Organic
# 206   SKU-0207     Organic - Variant 4  Food & Beverage      Organic
#
#      unit_cost  selling_price  shipping_cost_per_unit  weight_lbs    supplier
# ...

# %%
df2 = pd.read_csv("C:\\Users\\HP\\Downloads\\orders (1).csv")
df2
# Out:
#         order_id customer_id  order_date      channel     payment_method  \
# 0     ORD-000001      C-0617  2025-06-24   Mobile App          Gift Card
# 1     ORD-000002      C-0720  2025-08-23      Website        Credit Card
# 2     ORD-000003      C-0189  2025-07-20      Website        Credit Card
# 3     ORD-000004      C-0058  2025-07-17   Mobile App         Debit Card
# 4     ORD-000005      C-0580  2025-10-11  Marketplace        Credit Card
# ...          ...         ...         ...          ...                ...
# 1995  ORD-001996      C-0250  2025-09-06   Mobile App         Debit Card
# 1996  ORD-001997      C-0652  2025-06-27   Mobile App  Buy Now Pay Later
# 1997  ORD-001998      C-0473  2025-01-20  Marketplace        Credit Card
# 1998  ORD-001999      C-0784  2025-08-14      Website        Credit Card
# 1999  ORD-002000      C-0377  2025-11-21      Website        Credit Card
#
#          region  items_ordered primary_category  gross_revenue  discount_pct  \
# ...

# %%
df3 = pd.read_csv("C:\\Users\\HP\\Downloads\\marketing_spend.csv")
df3
# Out:
#        month         platform    spend  impressions  clicks  conversions  \
# 0    2024-01       Google Ads  2676.14       303594   13271          500
# 1    2024-01     Facebook Ads  1971.43       338022    7163          333
# 2    2024-01    Instagram Ads  2418.95       561361   18729          748
# 3    2024-01       TikTok Ads  1141.70       554273    6967          346
# 4    2024-01  Email Marketing   868.82        29509    1215           58
# ..       ...              ...      ...          ...     ...          ...
# 139  2025-12     Facebook Ads  7480.08      1454093   34543         2668
# 140  2025-12    Instagram Ads  5671.66       910841   21625          869
# 141  2025-12       TikTok Ads  3408.50       755034   18046         1171
# 142  2025-12  Email Marketing  1796.66        15675     477           11
# 143  2025-12       Influencer  6329.25       337538   17751         1374
#
#      revenue_attributed   cpc     cpa   roas
# 0              43063.16  0.20    5.35  16.09
# ...

# %%
df2.groupby('primary_category')['order_id'].count()
# Out:
# primary_category
# Beauty             205
# Books              239
# Clothing           293
# Electronics        267
# Food & Beverage    247
# Home & Kitchen     200
# Sports             292
# Toys               257
# Name: order_id, dtype: int64
